# %% [markdown]
# <a href="https://colab.research.google.com/github/jiin124/review_project/blob/main/modeling/%EC%95%84%EA%B3%A0%EB%8B%A4_%ED%98%B8%ED%85%94%EB%A6%AC%EB%B7%B0_Koelectra_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Koelectra
#
#
#
# ```
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11913 entries, 0 to 11912
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   star             11912 non-null  float64
#  1   Hotel_name       11912 non-null  object
#  2   reviewer_name    11898 non-null  object
#  3   trip_type        11913 non-null  object
#  4   room_type        10751 non-null  object
#  5   trip_date_year   11842 non-null  float64
#  6   trip_date_month  11842 non-null  float64
#  7   title            11906 non-null  object
#  8   review           11670 non-null  object
#  9   trip_day         11635 non-null  float64
#  10  review_date      11913 non-null  object
#  11  rate             11913 non-null  int64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.1+ MB
# ```

# %%
#한글 그래프 출력을 위한 
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
pip install datasets

# %% [markdown]
# 여기까지 돌리고 다시 런타임 돌리기

# %% [markdown]
# # 모듈 임포트

# %%
#한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager,rc

font_path="/content/drive/MyDrive/NanumSquareB.ttf"
font=font_manager.FontProperties(fname=font_path)

# %%
import matplotlib.pyplot as plt
plt.rc('font',family='NanumBarunGothic')

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from typing import Dict, List, Set, Callable, Optional
plt.style.use('ggplot')

# %%
#seed값 조정
import random
import os

def seed_everything(seed):
  random.seed(seed)
  os.environ['PYTHONHASHSEED']=str(seed)
  np.random.seed(seed)

seed_everything(42)

# %% [markdown]
# # 데이터 로드

# %%
df=pd.read_csv('/content/hotel_review_4_clean.csv')
df.head()
# Out:
#    star   Hotel_name reviewer_name        trip_type  \
# 0   4.0  스카이베이 호텔 경포            In           그룹 여행객
# 1   4.0  스카이베이 호텔 경포           Jae  유아/아동 동반 가족 여행객
# 2   4.0  스카이베이 호텔 경포         jeong        커플/2인 여행객
# 3   4.0  스카이베이 호텔 경포          suha          나홀로 여행객
# 4   4.0  스카이베이 호텔 경포       TAEHYUN        커플/2인 여행객
#
#                                room_type  trip_date_year  trip_date_month  \
# 0                         이그제큐티브 트윈 (금연)          2022.0              4.0
# 1                         이그제큐티브 트윈 (금연)          2022.0              4.0
# 2                                디럭스 더블룸          2022.0              1.0
# 3  디럭스 레이크뷰 더블룸 (인피니티 풀 무료 이용(성인 2명) 포함)          2021.0              7.0
# 4          DELUXE 2 BEDS FOR NON-SMOKERS          2021.0              5.0
#
#              title                                             review  \
# 0       친구들과의 힐링여행  친구들과의 1박 2일 힐링여행으로 스카이베이 호텔 경포 예약을 하고 호텔에 도착했으...
# 1           서비스 최악                               위치가 좋은 것 빼고는 모든 게 최악
# 2              숙소가                                        너무 좁고 노후됐어요
# 3  두 번째 방문, 은 별로네요  처음에 갔을 때 기억이 너무 좋아 이번에도 예약했어요. 근데 두 번째는 별로였어요....
# 4           별로입니다.  풀장 이용 안 할 거면 그냥 일반 3성급이 더 좋을 듯... 조식도 가격 대비 결혼...
#
#    trip_day          review_date  rate
# 0       1.0  2022-04-23 00:00:00     1
# 1       1.0  2022-04-10 00:00:00     1
# 2       1.0  2022-01-16 00:00:00     1
# 3       1.0  2021-07-17 00:00:00     1
# 4       1.0  2021-05-22 00:00:00     1

# %%
df['review'][4]
# Out:
# '풀장 이용 안 할 거면 그냥 일반 3성급이 더 좋을 듯... 조식도 가격 대비 결혼식 뷔페급도 안됨. 그냥 밖에서 8천 원 짜이 국밥 먹는 게 남. 환경 생각한답시고 어메니티 샴푸 수건 말곤 다 사야 함 숙소 내부에서 신발 신고 돌아다녀야 하는 것도 불편하고 슬리퍼도 사야 삼'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11913 entries, 0 to 11912
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   star             11912 non-null  float64
#  1   Hotel_name       11912 non-null  object
#  2   reviewer_name    11898 non-null  object
#  3   trip_type        11913 non-null  object
#  4   room_type        10751 non-null  object
#  5   trip_date_year   11842 non-null  float64
#  6   trip_date_month  11842 non-null  float64
#  7   title            11906 non-null  object
#  8   review           11670 non-null  object
#  9   trip_day         11635 non-null  float64
#  10  review_date      11913 non-null  object
#  11  rate             11913 non-null  int64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
df=df.dropna(subset = ['review'])

# %%
df=df.dropna(subset = ['title'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11667 entries, 0 to 11912
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   star             11666 non-null  float64
#  1   Hotel_name       11666 non-null  object
#  2   reviewer_name    11652 non-null  object
#  3   trip_type        11667 non-null  object
#  4   room_type        10548 non-null  object
#  5   trip_date_year   11598 non-null  float64
#  6   trip_date_month  11598 non-null  float64
#  7   title            11667 non-null  object
#  8   review           11667 non-null  object
#  9   trip_day         11392 non-null  float64
#  10  review_date      11667 non-null  object
#  11  rate             11667 non-null  int64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# # 데이터 나누기

# %%
from sklearn.model_selection import train_test_split

train,test=train_test_split(df,test_size=0.05,random_state=42)

print(train.shape)
print(test.shape)
# Out:
# (11083, 12)
# (584, 12)

# %%
train.columns
# Out:
# Index(['star', 'Hotel_name', 'reviewer_name', 'trip_type', 'room_type',
#        'trip_date_year', 'trip_date_month', 'title', 'review', 'trip_day',
#        'review_date', 'rate'],
#       dtype='object')

# %%
train.drop(['star', 'Hotel_name', 'reviewer_name', 'trip_type', 'room_type',
       'trip_date_year', 'trip_date_month', 'title', 'trip_day',
       'review_date'],axis=1,inplace=True)

# %%
test.drop(['star', 'Hotel_name', 'reviewer_name', 'trip_type', 'room_type',
       'trip_date_year', 'trip_date_month', 'title', 'trip_day',
       'review_date'],axis=1,inplace=True)

# %%
test_rate=test['rate']
test=test.drop('rate',axis=1)

print(test.shape)
print(test_rate.shape)
# Out:
# (584, 1)
# (584,)

# %%
display(train.head())
print()
display(test.head())
display(test_rate)
# Out:
#                                                   review  rate
# 2407   청결하고 친절한 서비스. 위치는 최적이지만 아래층 객실인 이유 때문인지 모르겠지만 ...     4
# 2788   저 빼고 온 가족이 코로나 확진되어 도피처로 사흘 지냈어ㅎ 시설도 나쁘지 않고, 근...     5
# 1595   시설은 괜찮았는데 복도에 사 중국인 투숙객 돌아다니며 문열아달라고했는데... 좀 오...     4
# 11588                                                  굿     3
# 8788                                      내부가 협소하고 불편합니다     2
#                                                   review
# 1373                            숙박에 적절한 가격과 위치가 정말 좋았어요!
# 10936  3박을 했는데 넓기는 엄청 넓었으나 침대 컨디션 생각보다 많이 안 좋았고 샤워실 청...
# 6200     사진 보고 모두 오션뷰인 줄 알았는데, 옆 건물 벽 뷰. 오래 있으면 정신병 걸릴 듯
# 8151                                       방은 넓지만 에어컨 고장
# 2619   공덕역 9번 출구 바로 앞의 최고의 위치. 로비에서 체크인 후 바로 편의점 행 가능...
# 1373     5
# 10936    2
# 6200     1
# 8151     3
# 2619     4
#         ..
# 7467     3
# 10014    3
# 7110     1
# 346      5
# 2325     4
# Name: rate, Length: 596, dtype: int64

# %%
train.to_csv('train.csv',index=False)
test.to_csv('test.csv',index=False)
test_rate.to_csv('test_rate.csv',index=False)

# %%
train=pd.read_csv('/content/train.csv')
test=pd.read_csv('/content/test.csv')
test_rate=pd.read_csv('/content/test_rate.csv')

# %% [markdown]
# # modeling

# %%
pip install transformers

# %%
import torch
from transformers import AutoTokenizer,AutoModelForSequenceClassification
from transformers import EarlyStoppingCallback,TrainingArguments,Trainer
from transformers.tokenization_utils_base import BatchEncoding
from transformers.trainer_utils import EvalPrediction
from datasets import load_dataset
from datasets.arrow_dataset import Dataset
from sklearn.metrics import accuracy_score

# %%
MAX_LEN=128
VALID_SPLIT=0.1
EPOCHS=8
LEARNING_RATE=1e-5
DR_RATE=0.3
WARMUP_STEPS=500
WEIGHT_DECAY=0.01
METRIC='accuracy'

device=torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

#KoELECTRA Training
MODEL_NAME='koelectra'
MODEL_PATH='jaehyeong/koelectra-base-v3-generalized-sentiment-analysis'
BATCH_SIZE=64

# %% [markdown]
# # Load Datasets

# %%
LABELS=[1,2,3,4,5]
id2label={idx:label for idx,label in enumerate(LABELS)}
label2id={label:idx for idx,label in enumerate(LABELS)}
print(train.shape)
train.head()
# Out:
# (11083, 2)
#                                               review  rate
# 0  너무 더러워서 돈 내고 업그레이드해도 불만족스러웠어요. 조식을 그 돈 내고 먹은 것...     1
# 1  침구만 깨끗하고 나머지는 별로였어요 예약할 때 객실을 선택했는데 막상 갔더니 호텔 ...     2
# 2                                다른 트윈방에 비해서 넓고 좋아요!     5
# 3  숙소에 갔는데 예약 명단도 제대로 확인이 안다 어서 한참 있다가 겨우 숙소에 들어갔...     2
# 4                                            정말 아니었음     2

# %%
print(id2label)
print(label2id)
# Out:
# {0: 1, 1: 2, 2: 3, 3: 4, 4: 5}
# {1: 0, 2: 1, 3: 2, 4: 3, 5: 4}

# %%
test.head()
# Out:
#                                               review
# 0  룸 컨디션 좋았고 직원분들 친절하셨습니다. 다만 위치상 렌트하지 않는 분들은 택시를...
# 1                                      시댁 어른을 모셨던 호텔
# 2  솔직하게 약간 속은 느낌. 위치야 정할 때부터 보긴 봤지만 실제 체감은 중심가랑 너...
# 3                                       조용하고 쾌적했습니다.
# 4                                                좋아요

# %%
train_dataset=load_dataset('csv',data_files='/content/train.csv',split='train')
test_dataset=load_dataset('csv',data_files='/content/test.csv',split='train')
train_dataset=train_dataset.train_test_split(test_size=VALID_SPLIT)

#clear_output()
print(train_dataset['train'].shape,train_dataset['test'].shape,test_dataset.shape)
# Out:
# WARNING:datasets.builder:Using custom data configuration default-9fde289067fd1b24
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-9fde289067fd1b24/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-9fde289067fd1b24/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
# WARNING:datasets.builder:Using custom data configuration default-0f449086a4867594
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-0f449086a4867594/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-0f449086a4867594/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
# (9974, 2) (1109, 2) (584, 1)

# %%
display(train_dataset['train'])
print()
display(test_dataset)
# Out:
# Dataset({
#     features: ['review', 'rate'],
#     num_rows: 9974
# })
# Dataset({
#     features: ['review'],
#     num_rows: 584
# })

# %% [markdown]
# # Tokenization

# %%
def tokenize(model_path: str) -> Callable[[Dataset],BatchEncoding]:
    tokenizer = AutoTokenizer.from_pretrained(model_path, problem_type='multi_label_classification')
    #clear_output()
    return lambda examples: tokenizer(examples['review'], max_length=MAX_LEN, padding='max_length', truncation=True)

def one_hot(examples: Dataset) -> Dict[str,np.ndarray]:
    return {'labels':np.eye(len(LABELS))[label2id[examples['rate']]]}

def preprocess(data: Dataset, model_path: str, labeled=True) -> Dataset:
    encoded = data.map(tokenize(model_path), batched=True, remove_columns=['review'], load_from_cache_file=False)
    encoded = encoded.map(one_hot, remove_columns=['rate'], load_from_cache_file=False) if labeled else encoded
    encoded.set_format('torch')
    return encoded

# %% [markdown]
# # Load Model

# %%
def model(model_path: str) -> AutoModelForSequenceClassification:
    model = AutoModelForSequenceClassification.from_pretrained(
        model_path,
        problem_type='multi_label_classification',
        ignore_mismatched_sizes=True,
        num_labels=len(LABELS),
        id2label=id2label,
        label2id=label2id,).to(device)
    #clear_output()

    return model

# %%
def compute_metrics(p:EvalPrediction)->Dict[str,float]:
  predictions,labels=p
  y_pred=np.argmax(predictions,axis=1)
  y_true=np.argmax(labels,axis=1)
  return{
      'accuracy':accuracy_score(y_true=y_true,y_pred=y_pred),
  }

# %% [markdown]
# # Load Trainer

# %%
from pathlib import Path

def make_dirs(name:str)->Dict[str,str]:
  output_dir = os.path.join('./saved/models', name)
  logging_dir = os.path.join('./saved/logger', name)
  exist_ok = name == ''
  Path(output_dir).mkdir(parents=True, exist_ok=exist_ok)
  Path(logging_dir).mkdir(parents=True, exist_ok=exist_ok)
  return output_dir, logging_dir

def training_args(model_name: str) -> TrainingArguments:
    output_dir, logging_dir = make_dirs(model_name)
    return TrainingArguments(
        output_dir=output_dir,
        evaluation_strategy='epoch',
        save_strategy='epoch',
        num_train_epochs=EPOCHS,
        per_device_train_batch_size=BATCH_SIZE,
        per_device_eval_batch_size=BATCH_SIZE,
        learning_rate=LEARNING_RATE,
        warmup_steps=WARMUP_STEPS,
        weight_decay=WEIGHT_DECAY,
        logging_dir=logging_dir,
        load_best_model_at_end=True,
        metric_for_best_model=METRIC,
    )

def trainer(dataset: Dataset, model_name: str, model_path: str, labeled=True) -> Trainer:
    data_loader = preprocess(dataset, model_path, labeled)

    return Trainer(
        model=model(model_path),
        args=training_args(model_name),
        train_dataset=data_loader['train'],
        eval_dataset=data_loader['test'],
        compute_metrics=compute_metrics,
        callbacks = [EarlyStoppingCallback(3)],
    )

# %%
koelectra_trainer=trainer(train_dataset,MODEL_NAME,MODEL_PATH)
# Out:
#   0%|          | 0/10 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/9974 [00:00<?, ?ex/s]
#   0%|          | 0/1109 [00:00<?, ?ex/s]
# Downloading:   0%|          | 0.00/452M [00:00<?, ?B/s]
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at jaehyeong/koelectra-base-v3-generalized-sentiment-analysis and are newly initialized because the shapes did not match:
# - classifier.out_proj.weight: found shape torch.Size([2, 768]) in the checkpoint and torch.Size([5, 768]) in the model instantiated
# - classifier.out_proj.bias: found shape torch.Size([2]) in the checkpoint and torch.Size([5]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
koelectra_trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 9974
#   Num Epochs = 8
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1248
#     <div>
#
#       <progress value='1248' max='1248' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1248/1248 28:52, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.570730</td>
#       <td>0.407574</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.437619</td>
#       <td>0.426510</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.403740</td>
#       <td>0.447250</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.519800</td>
#       <td>0.384940</td>
#       <td>0.467989</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.519800</td>
#       <td>0.377974</td>
#       <td>0.494139</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.519800</td>
#       <td>0.377117</td>
#       <td>0.508566</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.369000</td>
#       <td>0.376028</td>
#       <td>0.516682</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.369000</td>
#       <td>0.377005</td>
#       <td>0.513977</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-156
# Configuration saved in ./saved/models/koelectra/checkpoint-156/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-156/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-312
# Configuration saved in ./saved/models/koelectra/checkpoint-312/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-312/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-468
# Configuration saved in ./saved/models/koelectra/checkpoint-468/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-468/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-624
# Configuration saved in ./saved/models/koelectra/checkpoint-624/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-624/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-780
# Configuration saved in ./saved/models/koelectra/checkpoint-780/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-780/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-936
# Configuration saved in ./saved/models/koelectra/checkpoint-936/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-936/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-1092
# Configuration saved in ./saved/models/koelectra/checkpoint-1092/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-1092/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-1248
# Configuration saved in ./saved/models/koelectra/checkpoint-1248/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-1248/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./saved/models/koelectra/checkpoint-1092 (score: 0.5166816952209198).
# TrainOutput(global_step=1248, training_loss=0.42450273953951323, metrics={'train_runtime': 1736.8472, 'train_samples_per_second': 45.941, 'train_steps_per_second': 0.719, 'total_flos': 5248680705871872.0, 'train_loss': 0.42450273953951323, 'epoch': 8.0})

# %%
#2차
koelectra_trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 9974
#   Num Epochs = 8
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1248
#     <div>
#
#       <progress value='624' max='1248' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 624/1248 14:32 < 14:35, 0.71 it/s, Epoch 4/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.376028</td>
#       <td>0.516682</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.376028</td>
#       <td>0.516682</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.376028</td>
#       <td>0.516682</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.343500</td>
#       <td>0.376028</td>
#       <td>0.516682</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-156
# Configuration saved in ./saved/models/koelectra/checkpoint-156/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-156/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-312
# Configuration saved in ./saved/models/koelectra/checkpoint-312/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-312/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-468
# Configuration saved in ./saved/models/koelectra/checkpoint-468/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-468/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
# Saving model checkpoint to ./saved/models/koelectra/checkpoint-624
# Configuration saved in ./saved/models/koelectra/checkpoint-624/config.json
# Model weights saved in ./saved/models/koelectra/checkpoint-624/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./saved/models/koelectra/checkpoint-156 (score: 0.5166816952209198).
# TrainOutput(global_step=624, training_loss=0.3435692909436348, metrics={'train_runtime': 874.1038, 'train_samples_per_second': 91.284, 'train_steps_per_second': 1.428, 'total_flos': 2624340352935936.0, 'train_loss': 0.3435692909436348, 'epoch': 4.0})

# %%
koelectra_trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 1109
#   Batch size = 64
#     <div>
#
#       <progress value='18' max='18' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18/18 00:08]
#     </div>
# {'eval_loss': 0.3760280907154083,
#  'eval_accuracy': 0.5166816952209198,
#  'eval_runtime': 8.7219,
#  'eval_samples_per_second': 127.151,
#  'eval_steps_per_second': 2.064,
#  'epoch': 4.0}

# %%
test_dataset = preprocess(test_dataset, MODEL_PATH, labeled=False)
result = koelectra_trainer.predict(test_dataset)
preds = np.vectorize(id2label.get)(np.argmax(result.predictions, axis=1))
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--jaehyeong--koelectra-base-v3-generalized-sentiment-analysis/snapshots/f77aac8b7a2a88515e168082dd298d9982e73edb/config.json
# Model config ElectraConfig {
#   "_name_or_path": "jaehyeong/koelectra-base-v3-generalized-sentiment-analysis",
#   "architectures": [
#     "ElectraForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "0",
#     "1": "1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "0": 0,
#     "1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "problem_type": "multi_label_classification",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
#   "summary_type": "first",
#   "summary_use_proj": true,
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 35000
# }
#
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--jaehyeong--koelectra-base-v3-generalized-sentiment-analysis/snapshots/f77aac8b7a2a88515e168082dd298d9982e73edb/vocab.txt
# loading file tokenizer.json from cache at None
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--jaehyeong--koelectra-base-v3-generalized-sentiment-analysis/snapshots/f77aac8b7a2a88515e168082dd298d9982e73edb/tokenizer_config.json
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--jaehyeong--koelectra-base-v3-generalized-sentiment-analysis/snapshots/f77aac8b7a2a88515e168082dd298d9982e73edb/config.json
# Model config ElectraConfig {
#   "_name_or_path": "jaehyeong/koelectra-base-v3-generalized-sentiment-analysis",
#   "architectures": [
#     "ElectraForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "0",
#     "1": "1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "0": 0,
#     "1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
#   "summary_type": "first",
#   "summary_use_proj": true,
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 35000
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--jaehyeong--koelectra-base-v3-generalized-sentiment-analysis/snapshots/f77aac8b7a2a88515e168082dd298d9982e73edb/config.json
# Model config ElectraConfig {
#   "_name_or_path": "jaehyeong/koelectra-base-v3-generalized-sentiment-analysis",
#   "architectures": [
#     "ElectraForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "0",
#     "1": "1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "0": 0,
#     "1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
#   "summary_type": "first",
#   "summary_use_proj": true,
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 35000
# }
#   0%|          | 0/1 [00:00<?, ?ba/s]
# ***** Running Prediction *****
#   Num examples = 584
#   Batch size = 64

# %%
len(preds)
# Out:
# 584

# %%
preds
# Out:
# array([4, 2, 3, 5, 5, 5, 2, 4, 2, 1, 5, 1, 2, 4, 2, 5, 1, 2, 4, 2, 3, 4,
#        5, 2, 1, 5, 5, 4, 2, 4, 4, 1, 4, 2, 4, 5, 2, 4, 1, 4, 3, 2, 3, 2,
#        2, 2, 5, 2, 2, 2, 4, 2, 1, 3, 2, 1, 4, 5, 4, 5, 2, 3, 5, 4, 5, 2,
#        3, 2, 1, 4, 5, 5, 2, 5, 5, 4, 4, 5, 2, 2, 2, 2, 2, 5, 5, 2, 4, 5,
#        3, 5, 5, 5, 5, 2, 3, 4, 5, 4, 2, 4, 1, 3, 1, 4, 2, 5, 2, 2, 4, 2,
#        3, 5, 2, 4, 2, 3, 2, 2, 5, 2, 5, 3, 4, 5, 2, 3, 5, 5, 3, 4, 5, 2,
#        4, 2, 5, 5, 2, 2, 2, 4, 2, 2, 3, 2, 5, 5, 2, 2, 5, 4, 5, 5, 2, 5,
#        3, 4, 4, 5, 5, 1, 4, 2, 2, 4, 3, 5, 5, 5, 2, 3, 2, 2, 3, 2, 2, 4,
#        5, 2, 2, 3, 4, 2, 5, 4, 3, 2, 5, 4, 3, 5, 3, 2, 2, 5, 2, 2, 5, 4,
#        2, 1, 1, 4, 5, 2, 3, 4, 2, 2, 4, 2, 4, 5, 2, 2, 5, 2, 2, 2, 1, 3,
#        4, 2, 2, 5, 2, 2, 2, 2, 1, 5, 5, 5, 2, 5, 2, 5, 1, 5, 4, 3, 5, 5,
#        2, 1, 2, 5, 2, 3, 2, 5, 4, 5, 5, 5, 2, 1, 5, 2, 3, 3, 1, 2, 1, 2,
#        1, 2, 4, 5, 3, 5, 2, 2, 2, 3, 4, 2, 4, 2, 5, 5, 5, 5, 5, 5, 5, 2,
#        4, 5, 5, 2, 2, 4, 5, 1, 4, 2, 4, 1, 5, 5, 1, 3, 3, 4, 4, 5, 2, 2,
#        3, 4, 2, 4, 4, 5, 4, 1, 3, 2, 4, 1, 4, 2, 5, 3, 2, 4, 2, 4, 4, 2,
#        5, 5, 2, 5, 2, 5, 5, 2, 5, 4, 5, 4, 5, 2, 1, 3, 5, 2, 2, 3, 3, 1,
#        1, 2, 2, 2, 4, 1, 2, 3, 1, 1, 2, 2, 5, 2, 2, 5, 3, 4, 1, 5, 2, 5,
#        1, 5, 5, 2, 5, 3, 2, 1, 4, 2, 5, 4, 3, 2, 3, 3, 5, 5, 3, 2, 3, 5,
#        5, 1, 2, 5, 2, 5, 5, 2, 1, 2, 4, 5, 4, 4, 5, 2, 5, 2, 3, 3, 1, 2,
#        3, 5, 5, 2, 5, 3, 4, 1, 2, 3, 2, 1, 2, 2, 2, 3, 3, 4, 2, 2, 2, 3,
#        2, 5, 5, 5, 4, 4, 5, 2, 1, 2, 5, 1, 2, 3, 5, 2, 5, 3, 2, 2, 3, 2,
#        3, 5, 2, 5, 4, 2, 3, 2, 1, 5, 4, 4, 5, 2, 2, 4, 3, 5, 3, 3, 3, 3,
#        3, 4, 5, 4, 2, 5, 3, 3, 5, 4, 3, 4, 2, 4, 3, 4, 5, 4, 4, 3, 2, 2,
#        5, 5, 5, 3, 5, 4, 1, 5, 5, 4, 2, 4, 1, 4, 2, 2, 4, 2, 3, 2, 1, 4,
#        3, 3, 5, 2, 2, 4, 5, 5, 4, 5, 4, 4, 2, 3, 3, 5, 2, 2, 2, 5, 5, 4,
#        2, 4, 4, 1, 2, 3, 4, 2, 3, 2, 2, 4, 4, 2, 3, 2, 4, 3, 1, 4, 2, 1,
#        5, 1, 3, 1, 5, 5, 5, 4, 5, 2, 4, 5])

# %%
test_rate['pred_rate']=preds

# %%
test_rate
# Out:
#      rate  pred_rate
# 0       3          4
# 1       2          2
# 2       3          3
# 3       5          5
# 4       5          5
# ..    ...        ...
# 579     4          4
# 580     3          5
# 581     2          2
# 582     5          4
# 583     5          5
#
# [584 rows x 2 columns]

# %%
test_rate['review']=test['review']

# %%
test_rate
# Out:
#      rate  pred_rate                                             review
# 0       3          4  룸 컨디션 좋았고 직원분들 친절하셨습니다. 다만 위치상 렌트하지 않는 분들은 택시를...
# 1       2          2                                      시댁 어른을 모셨던 호텔
# 2       3          3  솔직하게 약간 속은 느낌. 위치야 정할 때부터 보긴 봤지만 실제 체감은 중심가랑 너...
# 3       5          5                                       조용하고 쾌적했습니다.
# 4       5          5                                                좋아요
# ..    ...        ...                                                ...
# 579     4          4  호텔보다는 리조트에 중점을 둔 곳이라, 가족 여행에 특화되어 있음. 중문 근처 비즈...
# 580     3          5                                               좋았어요
# 581     2          2  후기도 좋고 사진도 청결해 보여서 선택했는데 구석구석 먼지도 너무 많고... 청소도...
# 582     5          4  레이트 체크아웃 이 장점! 깨끗하고 따뜻했으나 조금 건조한 편 주위에 맛집 많고 위...
# 583     5          5                    방 업그레이드돼서 더 큰 룸에 묵었는데 아주 만족했습니다
#
# [584 rows x 3 columns]

# %%
test_rate.to_csv('koelectra_preds.csv',index=False)
